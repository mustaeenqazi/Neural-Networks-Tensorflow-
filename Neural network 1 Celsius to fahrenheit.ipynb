# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import numpy as np

# %%
celcius_q = np.array([-40,-10,0,8,15,22,38], dtype = float)
fahrenheit_a = np.array([-40,14,32,46,59,72,100], dtype = float)
for i,c in enumerate(celcius_q):
  print("{} Degree celcius = {} Degree fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 Degree celcius = -40.0 Degree fahrenheit
# -10.0 Degree celcius = 14.0 Degree fahrenheit
# 0.0 Degree celcius = 32.0 Degree fahrenheit
# 8.0 Degree celcius = 46.0 Degree fahrenheit
# 15.0 Degree celcius = 59.0 Degree fahrenheit
# 22.0 Degree celcius = 72.0 Degree fahrenheit
# 38.0 Degree celcius = 100.0 Degree fahrenheit

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss ='mean_squared_error', optimizer = tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(celcius_q,fahrenheit_a,epochs=500,verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('epoch number')
plt.ylabel("loss magnitude")
plt.plot(history.history['loss'])

# %%
print(model.predict([100]))
# Out:
# [[211.33727]]

# %%
print("Internal varibales: {}".format(l0.get_weights()))
# Out:
# Internal varibales: [array([[1.8206218]], dtype=float32), array([29.275084], dtype=float32)]

# %%
l0 = tf.keras.layers.Dense(units = 4, input_shape=[1])# input shape describes the number of features in the input
l1 = tf.keras.layers.Dense(units = 4)
l2 = tf.keras.layers.Dense(units = 1)
model = tf.keras.Sequential([l0,l1,l2])
model.compile(loss = 'mean_squared_error', optimizer = tf.keras.optimizers.Adam(0.1))
model.fit(celcius_q, fahrenheit_a, epochs= 500, verbose = False)
print("finished training the model")
print(model.predict([100.0]))
print("model predicts that 100 celcius is: {}".format(model.predict([100.0])))
print("these are the l0 variables: {}".format(l0.get_weights()))
print("these are the l1 variables: {}".format(l1.get_weights()))
print("these are the l2 variables: {}".format(l2.get_weights()))
# Out:
# finished training the model
# [[211.74745]]
# model predicts that 100 celcius is: [[211.74745]]
# these are the l0 variables: [array([[-0.17989618, -0.7687756 ,  0.36450425,  0.01305183]],
#       dtype=float32), array([-3.339934 , -3.6729958,  3.6586378, -2.1351871], dtype=float32)]
# these are the l1 variables: [array([[ 0.9975804 ,  0.00750031,  0.9016007 ,  0.08639836],
#        [ 0.81715864,  0.8461435 , -0.42504713,  0.72242874],
#        [-0.98467374,  0.10256103, -1.1645248 ,  0.31029305],
#        [-0.0407703 , -0.22898015,  1.1102092 ,  0.10966948]],
#       dtype=float32), array([-3.5625777, -1.0353496, -3.429589 , -1.7430058], dtype=float32)]
# these are the l2 variables: [array([[-1.1841903 ],
#        [-0.130066  ],
#        [-0.9920391 ],
#        [-0.20176907]], dtype=float32), array([3.4585555], dtype=float32)]
